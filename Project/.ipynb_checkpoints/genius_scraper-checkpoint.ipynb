# %% [markdown]
# # Scraping

# %%
from lyricsgenius import Genius
import bs4 as BeautifulSoup
import re
import billboard
from dateutil import rrule
from datetime import datetime, timedelta
import pandas as pd

# %%
token = 'UNXh1BykDmagMbxVjcAeMXiwDhnkmgsDC3a2AM2YWRKzLhLDpxsRJzfdvXP2cXRZ'

# %%
genius = Genius(token)

# %%
JH = genius.search_song("Industry Baby")
# Out:
# Searching for "Industry Baby"...
# Done.

# %%
JH.lyrics
# Out:
# "INDUSTRY BABY Lyrics[Intro: Lil Nas X]\n(D-D-Daytrip took it to ten, hey)\nBaby back, ayy, couple racks, ayy\nCouple Grammys on him, couple plaques, ayy\nThat's a fact, ayy, throw it back, ayy\nThrow it back, ayy\n[Pre-Chorus: Lil Nas X]\nAnd this one is for the champions\nI ain't lost since I began, yeah\nFunny how you said it was the end, yeah\nThen I went did it again, yeah\n\n[Chorus: Lil Nas X]\nI told you long ago on the road\nI got what they waiting for\nI don't run from nothing, dog\nGet your soldiers, tell 'em I ain't layin' low\nYou was never really rooting for me anyway\nWhen I'm back up at the top, I wanna hear you say\nHe don't run from nothin', dog\nGet your soldiers, tell 'em that the break is over\n\n[Verse 1: Lil Nas X]\nUh, need to, uh\nNeed to get this album done\nNeed a couple number onеs\nNeed a plaque on every song\nNeed mе like one with Nicki now\nTell a rap nigga I don't see ya, hah\nI'm a pop nigga like Bieber, hah\nI don't fuck bitches, I'm queer, hah\nBut 
# ...

# %%
song = JH

# %%
s = song.to_dict()

# %%
print(s['lyrics'])
# Out:
# INDUSTRY BABY Lyrics[Intro: Lil Nas X]
# (D-D-Daytrip took it to ten, hey)
# Baby back, ayy, couple racks, ayy
# Couple Grammys on him, couple plaques, ayy
# That's a fact, ayy, throw it back, ayy
# Throw it back, ayy
# [Pre-Chorus: Lil Nas X]
# And this one is for the champions
# I ain't lost since I began, yeah
# Funny how you said it was the end, yeah
# Then I went did it again, yeah
#
# [Chorus: Lil Nas X]
# I told you long ago on the road
# I got what they waiting for
# I don't run from nothing, dog
# Get your soldiers, tell 'em I ain't layin' low
# You was never really rooting for me anyway
# When I'm back up at the top, I wanna hear you say
# He don't run from nothin', dog
# Get your soldiers, tell 'em that the break is over
#
# [Verse 1: Lil Nas X]
# Uh, need to, uh
# Need to get this album done
# Need a couple number onеs
# Need a plaque on every song
# Need mе like one with Nicki now
# Tell a rap nigga I don't see ya, hah
# I'm a pop nigga like Bieber, hah
# ...

# %%
chart = billboard.ChartData('hot-100', date="1960-01-04", fetch=True, timeout=25)
# Out:
# 'The Hot 100'

# %%
# Create empty dataframe
columns = ['title', 'artist', 'rank', 'date', 'weeks']
songInfo = pd.DataFrame(None, columns=columns)

start = datetime.strptime('Jan 4 1960', '%b %d %Y')
end = datetime.now()
end = datetime.strptime('Jan 4 1961', '%b %d %Y')

for dt in rrule.rrule(rrule.MONTHLY, dtstart=start, until=end):
    chart = billboard.ChartData('hot-100', date=dt.strftime("%Y-%m-%d"), fetch=True, timeout=25)
    for song in chart:
        if dt == start:
            songInfo.loc[len(songInfo)] = [song.title, song.artist, song.rank, dt.strftime("%Y-%m-%d"), song.weeks]
        else:
            if song.isNew:
                songInfo.loc[len(songInfo)] = [song.title, song.artist, song.rank, dt.strftime("%Y-%m-%d"), song.weeks]
            else:
                row = songInfo.loc[songInfo['title'] == song.title]
                if len(row) == 0:
                    songInfo.loc[len(songInfo)] = [song.title, song.artist, song.rank, dt.strftime("%Y-%m-%d"), song.weeks]
                elif song.rank > row["rank"].item():
                    row["rank"] = song.rank
                    row.date = dt.strftime("%Y-%m-%d")
# Out:
#          title        artist rank        date weeks
# 28  Teen Angel  Mark Dinning   29  1960-01-04     3
#           title          artist rank        date weeks
# 3  Running Bear  Johnny Preston    4  1960-01-04    12
#             title               artist rank        date weeks
# 50  Where Or When  Dion & The Belmonts   51  1960-01-04     2
#      title         artist rank        date weeks
# 0  El Paso  Marty Robbins    1  1960-01-04     9
#         title       artist rank        date weeks
# 66  Handy Man  Jimmy Jones   67  1960-01-04     2
#               title         artist rank        date weeks
# 64  Lonely Blue Boy  Conway Twitty   65  1960-01-04     2
# Empty DataFrame
# Columns: [title, artist, rank, date, weeks]
# Index: []
# <ipython-input-64-885a32f59a49>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Out:
# 1

# %%
# Out:
# hot-100 chart from 1960-01-04
# -----------------------------
# 1. 'El Paso' by Marty Robbins
# 2. 'Why' by Frankie Avalon
# 3. 'The Big Hurt' by Miss Toni Fisher
# 4. 'Running Bear' by Johnny Preston
# 5. 'Way Down Yonder In New Orleans' by Freddie Cannon
# 6. 'Heartaches By The Number' by Guy Mitchell
# 7. 'It's Time To Cry' by Paul Anka
# 8. 'Among My Souvenirs' by Connie Francis
# 9. 'Pretty Blue Eyes' by Steve Lawrence
# 10. 'Go, Jimmy, Go' by Jimmy Clanton
# 11. 'We Got Love' by Bobby Rydell
# 12. 'Mack The Knife' by Bobby Darin
# 13. 'The Village Of St. Bernadette' by Andy Williams
# 14. 'Uh! Oh! Part 2' by The Nutty Squirrels
# 15. 'Sandy' by Larry Hall
# 16. 'Hound Dog Man' by Fabian
# 17. 'Scarlet Ribbons (For Her Hair)' by The Browns
# 18. 'Smokie - Part 2' by Bill Black's Combo
# 19. 'Not One Minute More' by Della Reese
# 20. 'This Friendly World' by Fabian
# 21. 'In The Mood' by Ernie Fields & Orch.
# 22. 'The Little Drummer Boy' by The Harry Simeone Chorale
# ...
