# %%
import matplotlib as mpl
import pandas as pd
import matplotlib.pylab as plt
import matplotlib.dates as mdates
import numpy as np
from datetime import datetime
import networkx as nx
import netwulf as nw
from itertools import combinations
from collections import defaultdict
import random
from scipy import stats
from networkx.algorithms import community

seed = 1337
random.seed(seed)
np.random.seed(seed)

# %%
song_data = pd.read_pickle('songData.df')
print(f'Number of songs: {len(song_data)}')
# Out:
# Number of songs: 25419

# %%
song_data.head()
# Out:
#      released           artists  \
# 0        1957   [marty robbins]
# 1  1960-01-04  [frankie avalon]
# 3        1959  [johnny preston]
# 4  1960-01-04   [freddy cannon]
# 5  1960-01-04    [guy mitchell]
#
#                                               lyrics            genres  \
# 0  \nOut in the West Texas town of El Paso\nI fel...         [country]
# 1  I'll never let you go\nWhy? Because I love you...             [pop]
# 3  On the bank of the river\nStood Running Bear, ...             [pop]
# 4  Well, way down yonder in New Orleans\nIn the l...             [pop]
# 5  \nHeartaches by the number, troubles by the sc...  [country, cover]
#
#                             title
# 0                         El Paso
# 1                             Why
# 3                    Running Bear
# 4  Way Down Yonder in New Orleans
# 5        Heartaches by the Number

# %% [markdown]
# ## Create the network (graph)

# %%
all_artists = set()
artist_genres = dict()
artist_genres_count = defaultdict(lambda: defaultdict(lambda: 0))
for artists, genres in zip(song_data.artists, song_data.genres):
    for artist in artists:
        all_artists = all_artists.union(set([artist]))
        for genre in genres:
            artist_genres_count[artist][genre] += 1
        if artist in artist_genres.keys():
            artist_genres[artist] = artist_genres[artist].union(set(genres))
        else:
            artist_genres[artist] = set(genres)
        

all_artists = list(all_artists)
print(f'Number of unique artists: {len(all_artists)}')
# Out:
# Number of unique artists: 7855

# %%
max(artist_genres_count['chris brown'], key=artist_genres_count['chris brown'].get)
# Out:
# 'dmv'

# %%
genre_list = ['pop', 'rock', 'rap', 'r&b', 'country', 'soul', 
              'singer-songwriter', 'pop-rock', 'trap', 'ballad', 
             'soul pop', 'eighties', 'uk', 'seventies', 'soundtrack',
             'hip-hop']

# %%
G = nx.Graph()
for artist in all_artists:
    genre_exists = False
    for genre in genre_list:
        if genre in artist_genres_count[artist]:
            genre_exists = True
            break
    if not genre_exists:
        max_keys = ['other']
    else:
        max_val = max(artist_genres_count[artist].get(title) for title in genre_list if title in artist_genres_count[artist])
        max_keys = [k for k, v in artist_genres_count[artist].items() if v == max_val]
    G.add_node(artist, genres=max_keys[0])
    
G.number_of_nodes()
# Out:
# 7855

# %%
nx.get_node_attributes(G, "genres")
# Out:
# {'aaron tveit': 'pop',
#  'sponge': 'rock',
#  "jump 'n the saddle band": 'pop',
#  'suzanne fellini': 'rock',
#  'sailcat': 'pop',
#  'john valenti': 'rock',
#  'souldecision': 'rap',
#  'megan thee stallion': 'rap',
#  'gamblin hell': 'rap',
#  'jeezy': 'rap',
#  'joshua kadison': 'pop',
#  'bipolar sunshine': 'pop',
#  'the stone poneys': 'pop',
#  'keith murray': 'rap',
#  'brother marquis': 'rap',
#  'lea michele': 'pop',
#  'belouis some': 'rock',
#  'vince guaraldi trio': 'pop',
#  'bruce springsteen': 'rock',
#  'hugh jackman': 'pop',
#  "lil' zane": 'r&b',
#  'the silencers': 'pop',
#  'tommy lee': 'rock',
#  '2 unlimited': 'pop',
#  'marven southgate': 'rap',
#  'kenny allstar': 'rap',
#  'black moon': 'rap',
#  'herman brood': 'pop',
#  'john leguizamo': 'pop',
#  'public enemy': 'rap',
#  'percy sledge': 'pop',
#  'little river band': 'pop',
#  'maluma': 'pop',
#  'the mojo men': 'pop',
#  'celi bee': 'pop',
#  'jade': 'r&b',
#  'september': 'pop',
#  'the mauds': 'r&b',
#  'hippy-green': 'rap',
#  'cece peniston': 'pop',
#  'pure soul': 'r&b',
#  'm.o.p.': 'rap',
#  'cizzy': 'rap',
#  'jordan smith': 'pop',
#  'palmer': 'rock',
#  'jerome pradon': 'pop',
#  'nancy sinatra': 'pop',
#  'drake': 'rap',
#  'hootie_the blowfish': 'rock',
#  'country': 'pop',
#  'santa esmeralda': 'pop',
#  'suga': 'rap',
#  'el chicano': 'pop',
#  'the american breed': 'pop',
#  'n/a music group': 'rap',
#  'josey scott': 'rock',
#  'ron browz': 'rap',
#  'duffy': 'r&b',
#  'christion': 'rap',
#  'lady wray': 'r&b',
#  'patrick jude': 'pop',
#  'arthur alexander': 'pop',
#  'beck': 'rock',
#  'fox (uk)': 'pop',
#  'chris tomlin': 'country',
#  'robert parker (usa)': 'pop',
#  'teo': 'rap',
#  'south shore commission': 'r&b',
#  'bob': 'r&b',
#  'regina spektor': 'pop',
#  'goldlink': 'r&b',
#  'the rip chords': 'rock',
#  'tony sunshine': 'rap',
#  'eminem': 'rap',
#  'garland green': 'pop',
#  'dave': 'pop',
#  'kylie minogue': 'pop',
#  'mø': 'pop',
#  'mouth': 'pop',
#  "skankin' pickle": 'pop',
#  'joshua bassett': 'pop',
#  'don jagwarr': 'rap',
#  'leshaun': 'rap',
#  'jordan knight': 'pop',
#  'lord jamar': 'rap',
#  'loud luxury': 'pop',
#  'bunker hill': 'pop',
#  'buffy': 'pop',
#  'fort minor': 'rap',
#  'terry mcdermott': 'pop',
#  'janet devlin': 'pop',
#  'wendy': 'pop',
#  'sister 7': 'pop',
#  'voyage (band)': 'pop',
#  'roachford': 'pop',
#  'shakira': 'pop',
#  'larry verne': 'pop',
#  'moon martin': 'pop',
#  'starz (us)': 'pop',
#  'marv johnson': 'r&b',
#  'big k.r.i.t.': 'rap',
#  'emilia mitiku': 'pop',
#  'johnny rivers': 'pop',
#  'amerie': 'r&b',
#  'marcy playground': 'rock',
#  'naul (나얼)': 'pop',
#  'denise lopez': 'pop',
#  'jeannie c. riley': 'pop',
#  'rich kidz': 'pop',
#  'sharon bryant': 'r&b',
#  'candlebox': 'rock',
#  'brotherhood of man': 'pop',
#  'copywrite': 'rap',
#  'the animals': 'rock',
#  'wang chung': 'pop',
#  'chris lake': 'pop',
#  'macc duce': 'rap',
#  'florida georgia line': 'country',
#  'lil duval': 'rap',
#  'jackie english': 'r&b',
#  'the afters': 'rock',
#  'the rivieras': 'rock',
#  'denim': 'rock',
#  'five stairsteps': 'pop',
#  'pretenders': 'pop',
#  'amaru son': 'rap',
#  'tiny tim': 'pop',
#  'matthew grimm': 'rock',
#  'deane hawley': 'pop',
#  'the music explosion': 'rock',
#  'nokz78': 'rap',
#  'youngbloodz': 'rap',
#  'jessica simpson': 'pop',
#  'fifth harmony': 'pop',
#  "john o'banion": 'pop',
#  'david archuleta': 'pop',
#  'pinkfong (핑크퐁)': 'pop',
#  'benny the butcher': 'rap',
#  'the underachievers': 'rap',
#  'johnny yukon': 'pop',
#  'father mountain': 'rock',
#  'mc elroy': 'rap',
#  'donnie iris': 'pop',
#  'winger': 'rock',
#  'billie myers': 'r&b',
#  'city high': 'rap',
#  'ric-a-che': 'rap',
#  'beach bunny': 'pop',
#  'slaydondo': 'rap',
#  'dakota moon': 'pop',
#  'jimmy osmond': 'pop',
#  'latimore': 'r&b',
#  'bubba sparxxx': 'rap',
#  'the partridge family': 'pop',
#  'loggins_messina': 'pop',
#  'deee-lite': 'pop',
#  'levitti': 'rap',
#  'sandy stewart': 'pop',
#  'merrilee rush and the turnabouts': 'pop',
#  'redbone': 'rock',
#  'the neighbourhood': 'pop',
#  'emeli sandé': 'pop',
#  'mike clifford': 'pop',
#  'phoebe bridgers': 'country',
#  'rex smith': 'pop',
#  'natural selection': 'pop',
#  'hank thompson': 'country',
#  'marky mark and the funky bunch': 'rap',
#  'cgb': 'rap',
#  'status quo': 'pop',
#  "t'pau": 'pop',
#  'sydelog': 'rap',
#  'saving abel': 'rock',
#  'delbert mcclinton': 'pop',
#  '070 shake': 'rap',
#  'helen reddy': 'pop',
#  'mc eiht': 'rap',
#  'fingazz': 'rap',
#  'cherine anderson': 'pop',
#  'genya ravan': 'rock',
#  'the walker brothers': 'pop',
#  'chizzface32': 'pop',
#  'pink sweat$': 'pop',
#  "liz damon's orient express": 'pop',
#  'johnny tillotson': 'pop',
#  'clark': 'pop',
#  'chantay savage': 'r&b',
#  'ricegum': 'rap',
#  'billy joel': 'rock',
#  'dj miko': 'pop',
#  'andy grammer': 'pop',
#  'thomas luther “luke” bryan': 'country',
#  'lucie tiger': 'country',
#  'al wilson': 'pop',
#  'queens of the stone age': 'rock',
#  'the supremes and the temptations': 'pop',
#  'javein scarwin': 'rap',
#  'barbara lewis': 'pop',
#  'emitt rhodes': 'pop',
#  'aimee mann': 'pop',
#  'diane renay': 'pop',
#  'rod lauren': 'pop',
#  'jermaine jackson': 'pop',
#  'vesta williams': 'r&b',
#  'adam levine': 'pop',
#  'sylvan lacue': 'rap',
#  'coro': 'pop',
#  'fyr': 'rock',
#  'jenni fujita': 'rap',
#  'brooke white': 'pop',
#  'a-trak': 'pop',
#  'brand nubian': 'rap',
#  'get wet': 'pop',
#  'mino cinelu': 'pop',
#  'nick fradiani': 'pop',
#  'the tornadoes 74': 'pop',
#  'lorne greene': 'pop',
#  'sia': 'pop',
#  'soak': 'rock',
#  'take that': 'pop',
#  'harry nilsson': 'pop',
#  'ron and the dc crew': 'rap',
#  'ned miller': 'country',
#  'the first edition': 'pop',
#  'the new establishments': 'pop',
#  'david lasley': 'pop',
#  'the white buffalo': 'rock',
#  'nick isaiah': 'rap',
#  'thunder': 'pop',
#  'pebbles': 'r&b',
#  'peter brown': 'pop',
#  'sara evans': 'country',
#  'mary travers': 'pop',
#  'waterfront': 'pop',
#  'the farm': 'rock',
#  'dream (girl group)': 'pop',
#  'pink floyd': 'rock',
#  'bruce cockburn': 'rock',
#  'tower of power': 'pop',
#  'lil jon': 'rap',
#  'monie love': 'rap',
#  'smokie': 'rock',
#  'frank black and the catholics': 'rock',
#  'tim hardin': 'pop',
#  'gerry and the pacemakers': 'pop',
#  'rylo rodriguez': 'rap',
#  'robin mcnamara': 'pop',
#  'ciara': 'r&b',
#  'angel': 'pop',
#  'radiohead': 'rock',
#  'truancy tru': 'rap',
#  'simple plan': 'rock',
#  'steppenwolf': 'rock',
#  'bill brandon': 'pop',
#  'the alarm': 'pop',
#  'the dramatics': 'soul',
#  'godley': 'pop',
#  'zion i': 'rap',
#  'ali jones': 'rap',
#  'hedgehoppers anonymous': 'pop',
#  'kyle': 'pop',
#  'helen shapiro': 'pop',
#  'fish mooney': 'pop',
#  'jacob daley': 'rap',
#  'jesse jo stark': 'rock',
#  'dj suede the remix god': 'rap',
#  'regard': 'pop',
#  'new edition': 'r&b',
#  'neil diamond': 'rock',
#  'alan price set': 'rock',
#  'devvon terrell': 'r&b',
#  'lil reese': 'rap',
#  'raury': 'rap',
#  'm people': 'pop',
#  'tamara': 'r&b',
#  'daniel son (rap)': 'rap',
#  'the killers': 'rock',
#  'fergie': 'pop',
#  'calvin harris': 'pop',
#  'city boy': 'pop',
#  'tommy tutone': 'pop',
#  'daniel tosh': 'pop',
#  'ray smith': 'pop',
#  'naturally 7': 'pop',
#  'epmd': 'rap',
#  'barry young': 'pop',
#  'scritti politti': 'pop',
#  'branford marsalis': 'pop',
#  '3oh!3': 'pop',
#  'ilovemakonnen': 'pop',
#  'dana harris': 'pop',
#  'eddie': 'r&b',
#  'bryce vine': 'r&b',
#  'ayana': 'r&b',
#  'l.t.b.': 'rock',
#  'urgent': 'rock',
#  'napoleon xiv': 'pop',
#  'andrijko': 'rock',
#  'clarence reid': 'r&b',
#  'paul engemann': 'pop',
#  'basia': 'pop',
#  'kool g rap': 'rap',
#  'the poets (usa)': 'pop',
#  'the expressions': 'pop',
#  'montell jordan': 'r&b',
#  'curiosity killed the cat': 'pop',
#  'the zombies': 'rock',
#  'led zeppelin': 'rock',
#  '5ive': 'r&b',
#  'jennifer lawrence': 'pop',
#  'marlena shaw': 'pop',
#  'the jacksons': 'pop',
#  'dan reed network': 'pop',
#  'lee brice': 'country',
#  'steve aoki': 'pop',
#  'rebecca "rebekah" jordan': 'pop',
#  'killer mike': 'rap',
#  'dave dudley': 'country',
#  'luke bryan': 'country',
#  'sik world': 'rap',
#  'john paul young': 'pop',
#  'transvision vamp': 'pop',
#  'the rainbows': 'pop',
#  'tag team': 'rap',
#  'the premiers': 'rock',
#  'lou rawls': 'pop',
#  'albert king': 'pop',
#  'the voices': 'r&b',
#  'billy edd wheeler': 'pop',
#  'ayu brazil': 'pop',
#  'mc brains': 'rap',
#  'lyn collins': 'r&b',
#  'o.c. smith': 'r&b',
#  'o.g.c.': 'rap',
#  'emerson drive': 'country',
#  'cl': 'rap',
#  'michael franti': 'pop',
#  'hamilton_joe frank_reynolds': 'pop',
#  'kidd kidd': 'rap',
#  'domino': 'rap',
#  'apple music': 'pop',
#  'andru donalds': 'pop',
#  'the andrews sisters': 'pop',
#  'billy ray cyrus': 'country',
#  'troy shondell': 'pop',
#  'giggs': 'rap',
#  'emmy meli': 'pop',
#  'judy collins': 'pop',
#  'chris cuevas': 'pop',
#  'jimmy wayne': 'pop',
#  'roddy ricch': 'rap',
#  'for king': 'pop',
#  'the scotts': 'rap',
#  'dan hartman': 'pop',
#  'big time rush': 'pop',
#  'phil da agony': 'rap',
#  'bella poarch': 'pop',
#  'richie rich': 'rap',
#  'they sleep they dream': 'pop',
#  'jason ryterband': 'pop',
#  'the rumjacks': 'pop',
#  'steve martin': 'pop',
#  'ralph stanley': 'country',
#  'ideal (usa)': 'r&b',
#  'lil suzy': 'pop',
#  'to be continued..': 'rap',
#  'starpoint': 'pop',
#  'matthew wilder': 'pop',
#  'cymarron': 'pop',
#  's.s.o.': 'r&b',
#  'after 7': 'r&b',
#  'cyndi thomson': 'pop',
#  'brenda k. starr': 'pop',
#  'charli xcx': 'pop',
#  'milestone': 'r&b',
#  'j. dash': 'pop',
#  'restless heart': 'country',
#  'the formations': 'pop',
#  'santana': 'rock',
#  'florence welch': 'pop',
#  'fashawn': 'rap',
#  'taino': 'r&b',
#  'gustie': 'rap',
#  'locash': 'country',
#  'pilot': 'pop',
#  'frazer': 'rap',
#  'timi yuro': 'pop',
#  'bernadette carroll': 'pop',
#  'billy currington': 'country',
#  'the furious five': 'rap',
#  'clarence clemons': 'pop',
#  'highrise': 'rap',
#  'the famous flames': 'r&b',
#  'melanie fiona': 'pop',
#  'the butterflys': 'pop',
#  'rell': 'rap',
#  'scorch nagano': 'rap',
#  'sir mix-a-lot': 'rap',
#  'craig wayne boyd': 'country',
#  'young cisto': 'rap',
#  'cashmere cat': 'r&b',
#  'tems': 'pop',
#  'jane child': 'rock',
#  'g-eazy': 'rap',
#  'truth hurts': 'r&b',
#  'andy williams': 'pop',
#  "bishop don 'magic' juan": 'rap',
#  'matt nolan': 'pop',
#  'the nitty gritty dirt band': 'country',
#  'twilight ophera': 'pop',
#  'migos': 'rap',
#  'sounds orchestral': 'pop',
#  'the graces': 'rock',
#  'our lady peace': 'rock',
#  'gene thomas': 'r&b',
#  'nico': 'pop',
#  'cameo': 'r&b',
#  'the national': 'rock',
#  'cynthia': 'pop',
#  'dx staff': 'rap',
#  'chris webby': 'rap',
#  'carole king': 'pop',
#  'loleatta holloway': 'r&b',
#  'otis clay': 'pop',
#  'the vaccines': 'pop',
#  'dr. dre': 'rap',
#  'jeru the damaja': 'rap',
#  'william bell': 'pop',
#  'the undisputed truth': 'r&b',
#  'thompson square': 'country',
#  'book of love': 'pop',
#  'dave mason': 'pop',
#  'one direction': 'pop',
#  'balance': 'pop',
#  'st. lunatics': 'rap',
#  'the mystic moods': 'rock',
#  'jerry wallace': 'pop',
#  'benny bell': 'pop',
#  'link (entertainment)': 'r&b',
#  'julie roberts': 'pop',
#  'yk osiris': 'r&b',
#  'the presidentz': 'pop',
#  'yung silk': 'rap',
#  'busdriver': 'rap',
#  'talkshow boy': 'pop',
#  'the high': 'rap',
#  'thomas doherty': 'pop',
#  'the rat pack': 'pop',
#  'dorothy combs morrison': 'pop',
#  'original broadway cast of honeymoon in vegas': 'pop',
#  'dax': 'rap',
#  'iconz': 'pop',
#  'lrmadrigal': 'rap',
#  'd12': 'rap',
#  'commodores': 'r&b',
#  'bow wow': 'rap',
#  'saga (can)': 'rock',
#  'menajahtwa': 'rap',
#  'soluna': 'pop',
#  'chris rivers': 'rap',
#  'jim weatherly': 'pop',
#  'crew': 'r&b',
#  'pearl jam': 'rock',
#  'partynextdoor': 'r&b',
#  'verdelle smith': 'pop',
#  'regina': 'pop',
#  'the calling': 'pop',
#  'saint jhn': 'pop',
#  'joe turner': 'pop',
#  'blackgirl': 'r&b',
#  'kiss': 'rock',
#  'the paris sisters': 'pop',
#  'richie sambora': 'pop',
#  'lil nas x': 'pop',
#  'lisa "left eye" lopes': 'pop',
#  'texas': 'pop',
#  'hoagy carmichael': 'pop',
#  'mott the hoople': 'rock',
#  'the busboys': 'rock',
#  'choppa': 'rap',
#  'jefferson starship': 'pop',
#  'nice peter': 'rap',
#  'joanne stone': 'pop',
#  'mgmt': 'rock',
#  'big sean': 'rap',
#  'armin van buuren': 'pop',
#  'rejoice': 'pop',
#  'steelheart': 'rock',
#  'bloodpop®': 'pop',
#  'change': 'r&b',
#  'bay city rollers': 'pop',
#  'spacejam jiff': 'rap',
#  'patsy': 'country',
#  'love': 'rock',
#  'clipse': 'rap',
#  'jamieboy': 'pop',
#  'a day to remember': 'pop',
#  'band aid': 'pop',
#  'bryan white': 'pop',
#  'ace frehley': 'rock',
#  'kevin gates': 'rap',
#  'baauer': 'pop',
#  'don and juan': 'pop',
#  'funkmaster flex': 'rap',
#  'two friends': 'pop',
#  'times two': 'rock',
#  'clifford curry': 'pop',
#  'big p.i.g': 'rock',
#  'terri gibbs': 'country',
#  'little jackie': 'pop',
#  'adam lambert': 'pop',
#  'calum scott': 'pop',
#  'johnny kemp': 'r&b',
#  'cainon lamb': 'rap',
#  'wax uk': 'pop',
#  'the trashmen': 'rock',
#  'magazine 60': 'pop',
#  "livin' joy": 'pop',
#  'koko taylor': 'r&b',
#  'rob swift': 'rap',
#  'sharissa': 'r&b',
#  'ivisson legendas': 'pop',
#  'the vapors': 'rock',
#  'barbara george': 'pop',
#  'the volumes (doo wop)': 'r&b',
#  'cannonball adderley': 'pop',
#  'justin hayward': 'pop',
#  'mirabai ceiba': 'pop',
#  'paul weller': 'r&b',
#  'the stereos (doo-wop group)': 'pop',
#  'the edwin hawkins singers': 'pop',
#  'descendants 2 cast': 'pop',
#  'wilson pickett': 'r&b',
#  'ruffneck': 'pop',
#  'ginuwine': 'r&b',
#  'christina aguilera': 'pop',
#  'seether': 'rock',
#  'june carter cash': 'country',
#  'culture beat': 'pop',
#  'neon trees': 'pop',
#  'vic damone': 'pop',
#  'stevie woods': 'pop',
#  'white plains': 'pop',
#  'biscuit (usa)': 'rap',
#  'alex clare': 'rock',
#  'garrett nash': 'pop',
#  'the 5th dimension': 'pop',
#  'all time low': 'rock',
#  'the exciters': 'pop',
#  'treach': 'rap',
#  'natural': 'rap',
#  'lefty frizzell': 'country',
#  'tracey lee': 'rap',
#  'the ronettes': 'pop',
#  'suga free': 'rap',
#  'original broadway cast of "hamilton"': 'rap',
#  'ying yang twins': 'rap',
#  'bobby moore': 'pop',
#  '95 south': 'rap',
#  'hall_oates': 'pop',
#  'lena zavaroni': 'pop',
#  'andrew ridgeley': 'pop',
#  'hollis': 'rap',
#  'barry manilow': 'pop',
#  'warrant': 'rock',
#  'love spit love': 'rock',
#  'hozier': 'rock',
#  'default': 'rock',
#  'toxic field mice': 'rock',
#  'b.b. king': 'pop',
#  'the five americans': 'pop',
#  'climax': 'pop',
#  'gardner': 'pop',
#  'david laflamme': 'pop',
#  'yarbrough': 'r&b',
#  'fantastic johnny c': 'r&b',
#  'hardboy': 'rock',
#  'susan jacks': 'pop',
#  'ewan maccoll': 'country',
#  'brian wilson': 'pop',
#  "shaquille o'neal": 'rap',
#  'tom powers': 'pop',
#  'jme': 'rap',
#  'jennifer lopez': 'pop',
#  'julian lennon': 'rock',
#  'chris young': 'country',
#  'georgie fame': 'r&b',
#  'vanity': 'pop',
#  'saigon': 'rap',
#  '1927': 'rock',
#  'house of lords': 'pop',
#  'the marvelettes': 'pop',
#  'tamar braxton': 'r&b',
#  'kate bush': 'rock',
#  'kathy mattea': 'pop',
#  'the-dream': 'rap',
#  'thomas doherty,': 'pop',
#  'suzi quatro': 'pop',
#  'l boogz': 'rap',
#  'wham!': 'pop',
#  'ms adventures': 'pop',
#  'jackie ross': 'r&b',
#  'wolfieszn ft yung silk': 'rap',
#  'darksied': 'rap',
#  'krizz kaliko': 'rap',
#  'frankie smith': 'rap',
#  'bert sommer': 'rock',
#  'baro sura': 'pop',
#  'robert knight': 'pop',
#  'chic': 'pop',
#  'kill the vultures': 'rap',
#  'barry mann': 'pop',
#  'new boyz': 'rap',
#  'joni mitchell': 'rock',
#  'the shadows': 'pop',
#  'gregg allman': 'pop',
#  'the world famous tony williams': 'r&b',
#  'jerry vale': 'pop',
#  'fantasia': 'r&b',
#  'the sandpebbles': 'pop',
#  'charm farm': 'pop',
#  'dan hill': 'pop',
#  'people under the stairs': 'rap',
#  'kelly rowland': 'r&b',
#  'marty balin': 'pop',
#  'rafael casal': 'rap',
#  'el debarge': 'r&b',
#  'don ray': 'pop',
#  'gary': 'pop',
#  'average white band': 'pop',
#  'joe south': 'pop',
#  'karla bonoff': 'pop',
#  'bird york': 'pop',
#  'the icicle works': 'rock',
#  'c-side': 'pop',
#  'the young rumblers': 'pop',
#  'mr. big': 'rock',
#  'dj drama': 'rap',
#  'glass tiger': 'pop',
#  "michel'le": 'rap',
#  'my darkest days': 'rock',
#  'marcos hernandez': 'rap',
#  'paul hardcastle': 'pop',
#  'anthony hamilton': 'r&b',
#  'billie rose': 'rap',
#  'andrew mcmahon in the wilderness': 'rock',
#  'maurice gibb': 'pop',
#  'lolita': 'pop',
#  'ray-n (rapper)': 'rap',
#  '7th': 'rap',
#  'wbn drain': 'rap',
#  'black eyed peas': 'pop',
#  'eddie money': 'pop',
#  'rae sremmurd': 'rap',
#  'pleasure': 'r&b',
#  'david sanborn': 'pop',
#  "the go-go's": 'pop',
#  'ugly kid joe': 'rock',
#  'kali uchis': 'pop',
#  'chingy': 'rap',
#  'bun b': 'rap',
#  'sleepy la beef': 'pop',
#  'kristine w': 'pop',
#  'isle of man': 'rock',
#  'jeremiah bligen': 'rap',
#  'lil ugly mane': 'rap',
#  'james carr': 'r&b',
#  'white lion': 'pop',
#  'axel': 'rap',
#  'dorrough music': 'rap',
#  'martin garrix': 'pop',
#  'dark dave': 'rap',
#  'brownstone': 'pop',
#  'mandy moore': 'pop',
#  'dustin lynch': 'country',
#  'muni long': 'r&b',
#  'jars of clay': 'rock',
#  'fats domino': 'pop',
#  'jerry lee lewis': 'rock',
#  'ernie maresca': 'pop',
#  'sob x rbe': 'rap',
#  'jojo, kevon edmonds': 'r&b',
#  'timmy t': 'pop',
#  'diamond head': 'pop',
#  'the kane gang': 'country',
#  'art linkletter': 'pop',
#  'trinidad james': 'rap',
#  'olamide': 'pop',
#  'del the funky homosapien': 'rock',
#  'rozetta johnson': 'r&b',
#  'quicksilver messenger service': 'rock',
#  'exile (band)': 'country',
#  'henry mancini': 'pop',
#  'kasenetz katz singing orchestral circus': 'rock',
#  'the dave clark five': 'pop',
#  'gerry rafferty': 'pop',
#  'barren': 'rap',
#  'the pips': 'pop',
#  'the clique': 'pop',
#  'death cab for cutie': 'rock',
#  'mad cobra': 'rap',
#  'travis': 'rock',
#  'midi maxi': 'pop',
#  'disco tex': 'pop',
#  'flash cadillac': 'pop',
#  'ben folds': 'rock',
#  'the shadows of knight': 'pop',
#  'nina sky': 'rap',
#  'debelah morgan': 'pop',
#  'paul mccartney': 'rock',
#  'twisted sister': 'rock',
#  'eazy-e': 'rap',
#  'eternal': 'r&b',
#  'christopher cross': 'pop',
#  'chris brown': 'r&b',
#  'raydio': 'r&b',
#  'capital cities': 'pop',
#  'ugly duckling': 'rap',
#  'andrea martin': 'r&b',
#  'elliott yamin': 'pop',
#  "dr. buzzard's original savannah band": 'pop',
#  'master p': 'rap',
#  'the leaves': 'rock',
#  'frankie miller (country)': 'country',
#  'bee gees': 'pop',
#  "somethin' for the people": 'r&b',
#  'the sports (aus)': 'pop',
#  'the sequence': 'rap',
#  'rich garcia': 'rap',
#  'derek (rock)': 'pop',
#  'central line': 'pop',
#  'saygrace': 'rap',
#  'debbie dean': 'r&b',
#  'cake': 'rock',
#  'steve harley': 'pop',
#  'charlie dore': 'country',
#  'a*teens': 'pop',
#  'the belmonts': 'pop',
#  'cal smith': 'country',
#  'sade': 'pop',
#  'melvin edmonds': 'r&b',
#  'sylvia robinson': 'r&b',
#  'trick pony': 'country',
#  'the sapphires': 'pop',
#  'xdipx': 'rap',
#  'modern english': 'rock',
#  'neil patrick harris': 'pop',
#  'spandau ballet': 'pop',
#  'quiet child': 'r&b',
#  'townes van zandt': 'country',
#  'paperboy': 'rap',
#  'benji madden': 'rock',
#  'alisan porter': 'country',
#  'maureen steele': 'pop',
#  'whitehead': 'r&b',
#  'commander cody and his lost planet airmen': 'pop',
#  'young zion 6600': 'rap',
#  'first choice': 'pop',
#  'shai': 'r&b',
#  'daniel rodriguez': 'pop',
#  'mondo rock': 'rock',
#  'reba mcentire': 'country',
#  'phoebe ryan': 'pop',
#  'leah andreone': 'pop',
#  'static-p': 'pop',
#  'lenny welch': 'pop',
#  'skepta': 'rap',
#  'dawn penn': 'rock',
#  'john hall': 'rock',
#  'veeze': 'rap',
#  'pressha': 'r&b',
#  'the lost civilization': 'pop',
#  'bill anderson': 'country',
#  'manassas': 'pop',
#  'harry chapin': 'rock',
#  'funkadelic': 'rock',
#  'ace (uk)': 'rock',
#  'double (swiss duo)': 'pop',
#  't-boz': 'r&b',
#  'jacob sartorius': 'pop',
#  'jeffrey osborne': 'r&b',
#  'mc serch': 'rap',
#  'zay hilfigerrr': 'rap',
#  'candy and the kisses': 'pop',
#  'prince and the revolution': 'r&b',
#  'gin blossoms': 'rock',
#  'raindrops': 'pop',
#  'born jamericans': 'pop',
#  'the delrons': 'pop',
#  'hoku clements': 'pop',
#  'ben rector': 'pop',
#  'paul stanley': 'pop',
#  'wilson phillips': 'pop',
#  'asia': 'rock',
#  'spacehog': 'rock',
#  'garnet mimms and the enchanters': 'r&b',
#  'jack': 'rap',
#  'trudy packmore': 'pop',
#  'hotlegs': 'pop',
#  'katie lopez': 'pop',
#  'mica paris': 'r&b',
#  'damien lawson': 'pop',
#  'connie francis': 'pop',
#  'spooks': 'rap',
#  'argent': 'rock',
#  'skrapz': 'rap',
#  'his cupcakes': 'pop',
#  'usher': 'r&b',
#  'big maybelle': 'pop',
#  'the shirelles': 'pop',
#  'the all-american rejects': 'rock',
#  'meat loaf': 'rock',
#  'artists united against apartheid': 'r&b',
#  'dr. calypso': 'pop',
#  'jackson wetherbee': 'rap',
#  'landon cube': 'rap',
#  'chaka khan': 'r&b',
#  'three dog night': 'pop',
#  'smiley': 'rap',
#  'est gee': 'rap',
#  'mabel': 'r&b',
#  'eddie rabbitt': 'country',
#  'kid kern': 'rap',
#  'mohombi': 'r&b',
#  'ckay': 'r&b',
#  'ed lover': 'rap',
#  'michael stipe': 'pop',
#  'thelma houston': 'r&b',
#  'the clean (nz)': 'pop',
#  'the lady of rage': 'rap',
#  'maine event': 'rap',
#  'kim sozzi': 'pop',
#  'the pussycat dolls': 'pop',
#  'sybil': 'pop',
#  'stone temple pilots': 'rock',
#  'heather b.': 'rap',
#  'connie francis, hank hunter, gary weston': 'pop',
#  'yg': 'rap',
#  'the detergents': 'pop',
#  'troop': 'r&b',
#  'ben colder': 'pop',
#  'willie nelson': 'country',
#  'lita ford': 'rock',
#  'kevin rudolf': 'pop',
#  'baltimora': 'pop',
#  'big scarr': 'rap',
#  'amazulu': 'pop',
#  'doctor ice': 'pop',
#  'litty rappin': 'rap',
#  'agatha lee monn': 'pop',
#  'sofi tukker': 'pop',
#  'buddy knox': 'pop',
#  'edwin starr': 'pop',
#  'the silencers (us)': 'rock',
#  'three days grace': 'rock',
#  'dr. dooom': 'rap',
#  'rose royce': 'r&b',
#  'steve lawrence': 'pop',
#  'bobby vee': 'pop',
#  'a perfect circle': 'rock',
#  'carolina gaitán': 'pop',
#  'alice deejay': 'pop',
#  'anonymous': 'rap',
#  'spiral starecase': 'pop',
#  'los umbrellos': 'pop',
#  'o-town': 'pop',
#  'reel 2 real': 'rap',
#  'juvenile-wacko-skip': 'pop',
#  'bella denapoli': 'pop',
#  'poison pen': 'rap',
#  'fantastic four': 'pop',
#  'danny williams': 'pop',
#  'isaiah rashad': 'rap',
#  'monyon tuda': 'rap',
#  'john fred': 'rock',
#  'foghat': 'pop',
#  'johnny hates jazz': 'pop',
#  'jojo': 'r&b',
#  'kool moe dee': 'rap',
#  'roman gianarthur': 'r&b',
#  'bobby peterson': 'r&b',
#  'matthew santos': 'rap',
#  'musique': 'pop',
#  'dean martin': 'pop',
#  'a$ap rocky': 'rap',
#  'the cure': 'rock',
#  'n0va': 'rap',
#  'meshell ndegéocello': 'r&b',
#  'virginia to vegas': 'pop',
#  'sza': 'r&b',
#  'the psychedelic furs': 'rock',
#  "gary's gang": 'pop',
#  'dmvmisfit': 'pop',
#  'curtis lee': 'rock',
#  'sammy masters': 'pop',
#  'crystal gayle': 'pop',
#  'frozen ghost': 'pop',
#  'mister d': 'pop',
#  'the trammps': 'pop',
#  'no doubt': 'pop',
#  'moms mabley': 'pop',
#  'kia jeffries': 'rap',
#  'bumps inf': 'rap',
#  'stars on 45': 'pop',
#  'father mc': 'r&b',
#  'jason evigan': 'pop',
#  'olivia': 'rap',
#  'lee dewyze': 'pop',
#  'tony green': 'pop',
#  'lil wayne': 'rap',
#  'madness': 'pop',
#  'the gap band': 'r&b',
#  'bros': 'pop',
#  'the happenings': 'pop',
#  'willow': 'pop',
#  'robin clark': 'rock',
#  'wayne anthony': 'pop',
#  'david foster': 'pop',
#  'mr. big (uk band)': 'pop',
#  'frank gari': 'pop',
#  'anthony melillo': 'pop',
#  'american memories': 'rock',
#  'nocap': 'rap',
#  't-pain': 'rap',
#  'guy sebastian': 'pop',
#  'garrett hedlund': 'pop',
#  'joe diffie': 'country',
#  'think': 'pop',
#  'alex aiono': 'pop',
#  'bia': 'rap',
#  'dnce': 'pop',
#  'claudine clark': 'r&b',
#  'gayle': 'pop',
#  'offset': 'rap',
#  'kool': 'r&b',
#  'stillharley': 'rap',
#  'brett eldredge': 'country',
#  'nervo': 'pop',
#  'marshall hain': 'pop',
#  'guy marks': 'pop',
#  'zombie nation': 'pop',
#  'hawks': 'rock',
#  'the parliaments': 'pop',
#  'ollie': 'pop',
#  'ross bagdasarian': 'pop',
#  'bryan ferry': 'rock',
#  'arthur prysock': 'r&b',
#  'm/a/r/r/s': 'pop',
#  'crazy town': 'rock',
#  'matty g': 'rap',
#  'selena': 'pop',
#  'hd of bearfaced': 'rap',
#  'loverboy': 'pop',
#  'oliver reed': 'pop',
#  'chamillionaire': 'rap',
#  'day26': 'pop',
#  'buckcherry': 'rock',
#  'lou bega': 'pop',
#  'hagar schon aaronson shrieve': 'rock',
#  'bonham': 'pop',
#  'allan kingdom': 'rap',
#  'surf mesa': 'pop',
#  'neil tennant': 'pop',
#  'the manhattan transfer': 'pop',
#  'terry callier': 'pop',
#  'miss a': 'pop',
#  'shareefa': 'r&b',
#  'the rolling stones': 'rock',
#  'thunderclap newman': 'pop',
#  'the playboys': 'pop',
#  'gorilla warfare tactics': 'rap',
#  'the murmurs': 'pop',
#  'shanell': 'rap',
#  'forgotten': 'rap',
#  'mat kearney': 'pop',
#  'mr. tan': 'r&b',
#  'david thorne': 'pop',
#  'leroy pullins': 'pop',
#  'playa': 'r&b',
#  'vitaliano': 'rap',
#  'jimmy clanton': 'pop',
#  'goodman': 'pop',
#  'tka': 'pop',
#  'yolanda adams': 'r&b',
#  'capleton': 'pop',
#  'jamey johnson': 'country',
#  'bobby byrd': 'r&b',
#  'keith': 'pop',
#  'holland-dozier': 'r&b',
#  'the regents': 'rock',
#  'graham central station': 'r&b',
#  'the neon philharmonic': 'pop',
#  'brenda holloway': 'pop',
#  'the dawn (ind)': 'pop',
#  'john lodge': 'pop',
#  'the power station': 'pop',
#  'c.j.': 'rock',
#  'darren hayes': 'pop',
#  'the hurricanes': 'pop',
#  'ab-soul': 'rap',
#  ...}

# %%
G.nodes['lin-manuel miranda']
# Out:
# {'genres': 'soundtrack'}

# %%
linked_artists = set()
for artists in song_data.artists:
    if len(artists) > 1:
        for comb in combinations(artists, 2):
            linked_artists = linked_artists.union(set([comb]))

linked_artists = list(linked_artists)
print(f'Number of edges: {len(linked_artists)}')
# Out:
# Number of edges: 7122

# %%
G.add_edges_from(linked_artists)
G.number_of_edges()
# Out:
# 6823

# %%
networkRand, config = nw.visualize(G, plot_in_cell_below=False)

# %%
new_G = nw.get_filtered_network(G, node_group_key='genres')
# G_partitioning = get_partitioning(new_G)
# karate_modularity = modularity(G, G_partitioning)

# %%
networkRand, config = nw.visualize(new_G, plot_in_cell_below=False)

# %% [markdown]
# ## Properties of the network

# %%
print(f'Number of Nodes: {G.number_of_nodes()}')
print(f'Number of Links: {G.number_of_edges()}')
print(f'Density: {nx.density(G):.5f}')

print(f'Avg. clustering: {nx.average_clustering(G):.2f}')
degrees = list(dict(G.degree()).values())
print(f'Average degrees: {np.mean(degrees):.2f}')
print(f'Median degrees: {np.median(degrees)}')
print(f'Mode of degrees: {stats.mode(degrees)[0][0]}')
print(f'Minimum degree: {min(degrees)}')
print(f'Maximum degree: {max(degrees)}')
# Out:
# Number of Nodes: 8407
# Number of Links: 9166
# Density: 0.00026
# Avg. clustering: 0.18
# Average degrees: 2.18
# Median degrees: 0.0
# Mode of degrees: 0
# Minimum degree: 0
# Maximum degree: 112

# %%
sorted_degrees = {k: v for k, v in sorted(dict(G.degree()).items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_degrees
# Out:
# {'lil wayne': 112,
#  'kanye west': 99,
#  'drake': 93,
#  'nicki minaj': 88,
#  'young thug': 84,
#  'chris brown': 71,
#  'yg': 62,
#  'travis scott': 62,
#  'jay-z': 61,
#  'future': 58,
#  'eminem': 56,
#  'ludacris': 55,
#  'fat joe': 52,
#  'snoop dogg': 51,
#  'dj khaled': 50,
#  'tyga': 49,
#  'rick ross': 49,
#  'killer mike': 49,
#  'big sean': 47,
#  'justin bieber': 47,
#  'nipsey hussle': 46,
#  'beyoncé': 46,
#  'prodigy of mobb deep': 46,
#  'lil baby': 46,
#  't.i.': 46,
#  't-pain': 44,
#  '2 chainz': 43,
#  'wiz khalifa': 42,
#  'raekwon': 42,
#  'pusha t': 41,
#  'problem': 41,
#  'meek mill': 40,
#  'diddy': 40,
#  'ty dolla $ign': 39,
#  'action bronson': 39,
#  'pitbull': 38,
#  'rockie fresh': 38,
#  'rihanna': 38,
#  'flatbush zombies': 38,
#  'missy elliott': 38,
#  'mary j. blige': 38,
#  'meyhem lauren': 37,
#  'mariah carey': 37,
#  'alexander spit': 36,
#  'zebra katz': 36,
#  'cuz lightyear': 36,
#  'bobby creekwater': 36,
#  'remy banks': 36,
#  'renegade el rey': 36,
#  'lil durk': 36,
#  'mike g': 36,
#  'two-9': 36,
#  'nigel nasty': 36,
#  'da$h': 36,
#  'kilo kish': 36,
#  'scotty atl': 36,
#  'retch': 36,
#  'bodega bamz': 36,
#  'noisey': 36,
#  'bryant dope': 36,
#  'pregnant boy': 36,
#  'del harris': 36,
#  'cyhi the prynce': 36,
#  'jennifer lopez': 36,
#  'heems': 36,
#  'pill': 36,
#  'danny brown': 36,
#  'yak ballz': 36,
#  'vado': 36,
#  'a$ton matthews': 36,
#  'dababy': 35,
#  '21 savage': 35,
#  'usher': 34,
#  'akon': 34,
#  'gucci mane': 34,
#  'kendrick lamar': 34,
#  'pharrell williams': 34,
#  'r. kelly': 33,
#  'lil uzi vert': 33,
#  'miley cyrus': 32,
#  'the weeknd': 32,
#  'post malone': 32,
#  'lil jon': 31,
#  'nelly': 30,
#  'camila cabello': 30,
#  'quavo': 29,
#  'ciara': 29,
#  'juice wrld': 29,
#  'll cool j': 28,
#  'joell ortiz': 28,
#  'lin-manuel miranda': 28,
#  'jacobymccraytm': 27,
#  'kxly06': 27,
#  'harttsick': 27,
#  'luvvi': 27,
#  'uxie': 27,
#  'tezzu': 27,
#  'j-thousand': 27,
#  'z1m': 27,
#  'fabolous': 27,
#  'enjoyhell': 27,
#  'a boogie wit da hoodie': 27,
#  'w3s': 27,
#  'yung keeta': 27,
#  'h4': 27,
#  'notzami': 27,
#  'cardi b': 27,
#  'flo rida': 27,
#  'm0tive': 27,
#  'sachel': 27,
#  'seph': 27,
#  'timbaland': 27,
#  'histarkey': 27,
#  'pop smoke': 27,
#  'cldsummer': 27,
#  'kei': 27,
#  'pingmas': 27,
#  'w1ll': 27,
#  'leo/zenny': 27,
#  'primm': 27,
#  'unifish': 27,
#  'siralbedo': 27,
#  'comet': 27,
#  'crrona': 27,
#  'terastic': 27,
#  'wale': 26,
#  'jermaine dupri': 26,
#  'nate dogg': 26,
#  'chance the rapper': 26,
#  'j balvin': 26,
#  'j. cole': 26,
#  'busta rhymes': 26,
#  'keyshia cole': 26,
#  'ashanti': 26,
#  'gunna': 26,
#  'john leguizamo': 25,
#  'jeremih': 25,
#  'a$ap rocky': 25,
#  'french montana': 25,
#  'trey songz': 25,
#  'anthony ramos': 25,
#  'nas': 25,
#  'ariana grande': 25,
#  '50 cent': 24,
#  'david guetta': 24,
#  'lil yachty': 24,
#  'polo g': 24,
#  'jeezy': 23,
#  'calvin harris': 23,
#  'kid cudi': 23,
#  'gloria estefan': 23,
#  'migos': 23,
#  'offset': 22,
#  'birdman': 22,
#  'master p': 22,
#  'fergie': 22,
#  'marc anthony': 22,
#  'khalid': 21,
#  'sheryl crow': 21,
#  'ne-yo': 21,
#  'luis fonsi': 21,
#  'peter cetera': 21,
#  'yo gotti': 21,
#  'will smith': 21,
#  'luther vandross': 21,
#  'céline dion': 21,
#  'umru': 20,
#  'yung skrrt': 20,
#  'william crooks': 20,
#  'dessa': 20,
#  '4kmirage': 20,
#  'bva': 20,
#  'dirty dike': 20,
#  'sebii': 20,
#  'fliptrix': 20,
#  'fraxiom': 20,
#  'left at london': 20,
#  'rita moreno': 20,
#  'justin timberlake': 20,
#  'pedro capó': 20,
#  'rodney chrome': 20,
#  'chester p': 20,
#  'ana villafañe': 20,
#  'tony velour': 20,
#  'klashnekoff': 20,
#  'mohawk johnson': 20,
#  'aaron cartier': 20,
#  'river moon': 20,
#  'petal supply': 20,
#  'alex lacamoire': 20,
#  'gilberto santa rosa': 20,
#  'gina rodriguez': 20,
#  'andrew goes to hell': 20,
#  'jedwill': 20,
#  'si philli': 20,
#  'cracker jon': 20,
#  'ed sheeran': 20,
#  'bill shakes': 20,
#  'verb t': 20,
#  'staple god': 20,
#  'leaf dog': 20,
#  'jack jetson': 20,
#  'kashmere': 20,
#  'eric the red': 20,
#  'roddy ricch': 20,
#  'farma g': 20,
#  'tommy torres': 20,
#  'neutra': 20,
#  'mystro': 20,
#  'remus blvk': 20,
#  'dj sammy b-side': 20,
#  'ando': 20,
#  'jehst': 20,
#  'lucy lohan': 20,
#  'smellington piff': 20,
#  'carrie underwood': 20,
#  'blake shelton': 20,
#  'hate shaliek': 20,
#  'tygko': 20,
#  'rubén blades': 20,
#  'sonnyjim': 20,
#  'ednita nazario': 20,
#  'pj sin suela': 20,
#  'life mc': 20,
#  'ralph tresvant': 19,
#  'bad bunny': 19,
#  'eve': 19,
#  'tyler, the creator': 19,
#  'marv won': 19,
#  'michael bolton': 19,
#  'trippie redd': 19,
#  'youngboy never broke again': 19,
#  'kodak black': 19,
#  'bobby brown': 19,
#  'enrique iglesias': 18,
#  'jody watley': 18,
#  'david bowie': 18,
#  'garth brooks': 18,
#  'janet jackson': 18,
#  'the-dream': 18,
#  'the pointer sisters': 18,
#  'randy travis': 18,
#  'daddy yankee': 18,
#  'little richard': 18,
#  'shady records': 18,
#  'bow wow': 18,
#  'natasha bedingfield': 18,
#  'stevie wonder': 17,
#  'brenda russell': 17,
#  'warren wiebe': 17,
#  'jani lane': 17,
#  'kathy mattea': 17,
#  'dej loaf': 17,
#  'anuel aa': 17,
#  'guilty simpson': 17,
#  "lil' kim": 17,
#  'ozuna': 17,
#  'will.i.am': 17,
#  'juicy j': 17,
#  'matthew nelson': 17,
#  'gunnar nelson': 17,
#  'voices that care': 17,
#  'jamie foxx': 17,
#  'ma$e': 16,
#  'sean paul': 16,
#  "cam'ron": 16,
#  'boldy james': 16,
#  'trick trick': 16,
#  'mack maine': 16,
#  'the game': 16,
#  'wyclef jean': 16,
#  'major lazer': 16,
#  'ja rule': 16,
#  'g-eazy': 16,
#  '2pac': 16,
#  'taylor swift': 16,
#  'z (of firing squad': 16,
#  'jfkray': 16,
#  'brooks': 16,
#  'selena gomez': 16,
#  'dikulz': 16,
#  'dmx': 15,
#  'silkk the shocker': 15,
#  'diezel the hitman': 15,
#  'john legend': 15,
#  'alan jackson': 15,
#  'melissa etheridge': 15,
#  'dr. dre': 15,
#  'demi lovato': 15,
#  'sino': 15,
#  'swae lee': 15,
#  'katy perry': 15,
#  'jhené aiko': 15,
#  'artists stand up to cancer': 15,
#  'big gov': 15,
#  'marshmello': 15,
#  'rustage': 15,
#  'black milk': 15,
#  'icewear vezzo': 15,
#  'kid vishis': 15,
#  'payroll giovanni': 15,
#  'paul wall': 15,
#  'george michael': 15,
#  'calicoe': 15,
#  'leona lewis': 15,
#  'redman': 15,
#  'big herk': 15,
#  'leann rimes': 15,
#  'detroit che': 15,
#  'joe': 14,
#  'twista': 14,
#  'plies': 14,
#  'jid': 14,
#  'lloyd banks': 14,
#  'kid ink': 14,
#  'yung joc': 14,
#  'glee cast': 14,
#  'g15 official': 14,
#  'alicia keys': 14,
#  'dreamville': 14,
#  'trick daddy': 14,
#  'ice cube': 14,
#  'big boi': 14,
#  'b.o.b': 14,
#  'e-40': 14,
#  'mystikal': 14,
#  'swizz beatz': 14,
#  'shofu': 14,
#  'twisted savvy': 13,
#  'kool': 13,
#  'summer walker': 13,
#  'shwabadi': 13,
#  'moneybagg yo': 13,
#  'young money': 13,
#  'da brat': 13,
#  'too $hort': 13,
#  'gameboyjones': 13,
#  'macklemore': 13,
#  'wisin': 13,
#  'fabvl': 13,
#  'vi seconds': 13,
#  'quincy jones': 13,
#  'dizzyeight': 13,
#  'jadakiss': 13,
#  'idina menzel': 13,
#  'mega ran': 13,
#  'kenny chesney': 13,
#  'andré 3000': 13,
#  'brad paisley': 13,
#  'youssoupha': 13,
#  'elton john': 13,
#  'megan thee stallion': 13,
#  'mýa': 13,
#  'frivolousshara': 13,
#  'don toliver': 13,
#  'pnb rock': 13,
#  'adam levine': 13,
#  'zach b': 13,
#  'connor quest!': 13,
#  'tyrese': 13,
#  'sinewave fox': 13,
#  'shao dow': 13,
#  'the gang, marilyn, paul mccartney, paul young, phil collins, spandau ballet, status quo, sting, the style council, u2': 12,
#  'the notorious b.i.g.': 12,
#  'gibby stites': 12,
#  'dj drama': 12,
#  'culture club': 12,
#  'zedd': 12,
#  'frankie goes to hollywood': 12,
#  'bananarama': 12,
#  'dionne warwick': 12,
#  'schoolboy q': 12,
#  'nav': 12,
#  '112': 12,
#  'kesha': 12,
#  'grimm gfx': 12,
#  'heaven 17': 12,
#  'bonez dubb': 12,
#  'duran duran': 12,
#  'shy one': 12,
#  'demi demaree': 12,
#  'bebe rexha': 12,
#  'paul mccartney': 12,
#  'big country': 12,
#  'fivio foreign': 12,
#  'c-mob': 12,
#  'bukshot': 12,
#  'miguel': 12,
#  'tory lanez': 12,
#  'metro boomin': 12,
#  'michael jackson': 12,
#  'cody manson': 12,
#  'ritual of ether': 12,
#  'bas': 12,
#  's.o.n. (usa': 12,
#  'dieabolik the monster': 12,
#  'the boomtown rats': 12,
#  'boondox': 12,
#  'skribbal': 12,
#  'lil pump': 12,
#  'christina aguilera': 12,
#  'band aid': 12,
#  'jae millz': 11,
#  'gudda gudda': 11,
#  'sza': 11,
#  'babyface': 11,
#  'mustard': 11,
#  'crucified': 11,
#  'machine gun kelly': 11,
#  'k-fix': 11,
#  'method man': 11,
#  'kehlani': 11,
#  'jagged edge': 11,
#  'robin thicke': 11,
#  'halsey': 11,
#  'fluenci': 11,
#  'bruno mars': 11,
#  'illest-uminati': 11,
#  '6ix9ine': 11,
#  'florida georgia line': 11,
#  'faith evans': 11,
#  'd.clark': 11,
#  'juelz santana': 11,
#  'waka flocka flame': 11,
#  'lil chuckee': 11,
#  'jason derulo': 11,
#  'jay crazii': 11,
#  'three 6 mafia': 11,
#  't-streets': 11,
#  'ski mask the slump god': 11,
#  'lil twist': 11,
#  'hurracane': 11,
#  'soulja boy': 11,
#  'yung statz': 11,
#  'smokepurpp': 11,
#  'the chainsmokers': 11,
#  'twistid rob': 11,
#  'sofia carson': 11,
#  'young stoner life': 11,
#  'shanell': 11,
#  'fetty wap': 11,
#  'mizury mize': 11,
#  "lil' mo": 10,
#  'grandmaster melle mel': 10,
#  'grünt': 10,
#  'booboo stewart': 10,
#  'china anne mcclain': 10,
#  'maroon 5': 10,
#  'cameron boyce': 10,
#  'the kid laroi': 10,
#  'skylar grey': 10,
#  'keith sweat': 10,
#  'shakira': 10,
#  'keith urban': 10,
#  'common': 10,
#  'rosalía': 10,
#  'dylan playfair': 10,
#  'afrojack': 10,
#  'brett eldredge': 10,
#  'lil tjay': 10,
#  'internet money': 10,
#  'blackstreet': 10,
#  'p!nk': 10,
#  'tech n9ne': 10,
#  'sech': 10,
#  'maluma': 10,
#  'g herbo': 10,
#  'playboi carti': 10,
#  'mez': 9,
#  'lupe fiasco': 9,
#  'dove cameron': 9,
#  'pearce joza': 9,
#  'nicky jam': 9,
#  'ryan lewis': 9,
#  'now': 9,
#  'adassa': 9,
#  'chandler kinney': 9,
#  'roscoe dash': 9,
#  'artists of then': 9,
#  'kevin gates': 9,
#  'almighty u-sorcerer': 9,
#  'buddy': 9,
#  'ginuwine': 9,
#  'quality control': 9,
#  'mike jones': 9,
#  'thomas doherty,': 9,
#  'reese laflare': 9,
#  'chingy': 9,
#  'dunn, carrie underwood, charley pride, darius rucker, dierks bentley, dolly parton, eric church, faith hill, george strait, jason aldean, kacey musgraves, keith urban, lady a, little big town, luke bryan, martina mcbride, miranda lambert, randy travis, rascal flatts, reba mcentire, ronnie milsap, tim mcgraw, trisha yearwood, vince gill': 9,
#  'forever': 9,
#  'xxxtentacion': 9,
#  'alabama': 9,
#  'aaliyah': 9,
#  'jace': 9,
#  'stephanie beatriz': 9,
#  'guapdad 4000': 9,
#  'bono': 9,
#  'big pun': 9,
#  'young buck': 9,
#  'dj snake': 9,
#  'dua lipa': 9,
#  'baby bash': 9,
#  'john lennon': 9,
#  'tainy': 9,
#  'king von': 9,
#  'baby ariel': 9,
#  'pooh shiesty': 8,
#  'the alchemist': 8,
#  'krayzie bone': 8,
#  'ray charles': 8,
#  'city girls': 8,
#  'sting': 8,
#  'rich homie quan': 8,
#  'august alsina': 8,
#  '42 dugg': 8,
#  'nina sky': 8,
#  'jack harlow': 8,
#  'sway': 8,
#  'young nudy': 8,
#  'anthony rapp': 8,
#  'kirk franklin': 8,
#  'athy': 8,
#  'new era': 8,
#  'mike will made-it': 8,
#  'original broadway cast of rent': 8,
#  'bumpman': 8,
#  'pimp c': 8,
#  'barbra streisand': 8,
#  'daphne rubin-vega': 8,
#  'logic': 8,
#  'tinie tempah': 8,
#  'mannie fresh': 8,
#  'q-tip': 8,
#  'bts': 8,
#  'darell': 8,
#  'boybettahknow': 8,
#  'daveed diggs': 8,
#  'the lonely island': 8,
#  'kelly rowland': 8,
#  'james blake': 8,
#  'chaka khan': 8,
#  'britney spears': 8,
#  'rae sremmurd': 8,
#  'rod stewart': 8,
#  'taye diggs': 8,
#  'jesse l. martin': 8,
#  'whitney houston': 8,
#  'keri hilson': 8,
#  'kenzin0': 8,
#  'fredi walker': 8,
#  'shaggy': 8,
#  'partynextdoor': 8,
#  'kelly price': 8,
#  'adam pascal': 8,
#  'wilson jermaine heredia': 8,
#  'a$ap ferg': 8,
#  'queen latifah': 8,
#  'thahiphophead': 8,
#  'peter gunz': 8,
#  'desiigner': 8,
#  'thomas rhett': 8,
#  'kygo': 8,
#  'charlie f': 8,
#  'strayakunt': 8,
#  'the east side boyz': 8,
#  'skrillex': 8,
#  'ying yang twins': 7,
#  'charlie puth': 7,
#  'chamillionaire': 7,
#  '6lack': 7,
#  'doums': 7,
#  'nakk mendosa': 7,
#  'harsha': 7,
#  'sia': 7,
#  'framal': 7,
#  'outkast': 7,
#  'zac efron': 7,
#  'sleepy brown': 7,
#  'sam smith': 7,
#  'zendaya': 7,
#  'r.l.': 7,
#  'donny_danko': 7,
#  'dixon': 7,
#  'mekra': 7,
#  'alpha wann': 7,
#  'ali jones': 7,
#  'sean kingston': 7,
#  'philip (ind': 7,
#  'r.e.d.k.': 7,
#  'kenny rogers': 7,
#  'a-list': 7,
#  'karol g': 7,
#  'mtyki': 7,
#  "shaquille o'neal": 7,
#  'ckoo': 7,
#  'nivea': 7,
#  'mr. magic': 7,
#  'jeff le nerf': 7,
#  'feyago': 7,
#  'mokless': 7,
#  'lino': 7,
#  'jennifer hudson': 7,
#  'tim mcgraw': 7,
#  'clint black': 7,
#  'h.e.r.': 7,
#  'c-murder': 7,
#  'ellie goulding': 7,
#  'remy ma': 7,
#  'népal': 7,
#  'kelis': 7,
#  'rob the imk': 7,
#  'hardknok': 7,
#  'tha eastsidaz': 7,
#  'romeo santos': 7,
#  'lady gaga': 7,
#  'mobb deep': 7,
#  'poison pen': 7,
#  'tevin campbell': 7,
#  'krazy': 7,
#  '2zer': 7,
#  'obie trice': 7,
#  '504 boyz': 7,
#  'mike m': 7,
#  'original broadway cast of "hamilton"': 7,
#  'the cypher projekt': 7,
#  'nekfeu': 7,
#  'iggy azalea': 7,
#  'jerry butler': 7,
#  'jay sean': 7,
#  'dunn': 7,
#  'kool moe dee': 7,
#  'cizzy': 7,
#  'bs-calrissian': 7,
#  'médine': 7,
#  'mac miller': 6,
#  'kamikazi': 6,
#  'sniper': 6,
#  'bizum': 6,
#  'charlie daniels': 6,
#  'labrinth': 6,
#  'coldplay': 6,
#  'michael mcdonald': 6,
#  'stitches': 6,
#  'reba mcentire': 6,
#  'tiësto': 6,
#  'boosie badazz': 6,
#  'ceelo green': 6,
#  'vita': 6,
#  'jonathan groff': 6,
#  'bryson tiller': 6,
#  'canardo': 6,
#  'christopher johnson': 6,
#  'salt-n-pepa': 6,
#  'lil duke': 6,
#  'esham': 6,
#  'big l': 6,
#  'barry gibb': 6,
#  'kris kross': 6,
#  'jason ryterband': 6,
#  'dick van dyke': 6,
#  'lmfao': 6,
#  'brantley gilbert': 6,
#  'spinderella': 6,
#  'stretch and bobbito': 6,
#  'bashy': 6,
#  'rich gang': 6,
#  'og kid frost': 6,
#  'fababy': 6,
#  'gwen stefani': 6,
#  'beef tha thief': 6,
#  'yandel, bad bunny, randy, cosculluela, nicky jam': 6,
#  'krs-one': 6,
#  'new boyz': 6,
#  'mic rahman': 6,
#  'dre': 6,
#  'children of the corn': 6,
#  'teoria do caos': 6,
#  'bobbito': 6,
#  'tateeze': 6,
#  'vince gill': 6,
#  'travie mccoy': 6,
#  'matt doyle': 6,
#  'the alumni': 6,
#  'barry white': 6,
#  'warllock': 6,
#  'charlie ray': 6,
#  'the pussycat dolls': 6,
#  'nicki minaj ft. lil wayne': 6,
#  'insane clown posse': 6,
#  'álvaro mamute': 6,
#  'lex luthoor': 6,
#  'gabelegal': 6,
#  'ghostface killah': 6,
#  'twisted insane': 6,
#  'hailee steinfeld': 6,
#  'cage': 6,
#  'scarface': 6,
#  'okieriete onaodowan': 6,
#  'dz svg': 6,
#  'ouija macc': 6,
#  'big tymers': 6,
#  'detail': 6,
#  'sultan': 6,
#  'chip': 6,
#  'bawal clan': 6,
#  'la fouine': 6,
#  'dj paul': 6,
#  'brent faiyaz': 6,
#  'aretha franklin': 6,
#  'project pat': 6,
#  'london on da track': 6,
#  'scorcher': 6,
#  'arma xiss': 6,
#  'jr.': 6,
#  'nio garcía': 6,
#  'dem franchize boyz': 6,
#  'manila money': 6,
#  'judith hill': 6,
#  'casper mágico': 6,
#  'james snyder': 6,
#  'leslie odom': 6,
#  'king iso': 6,
#  'olivia newton-john': 6,
#  'wretch 32': 6,
#  'omarion': 6,
#  'yfn lucci': 6,
#  'ricky martin': 6,
#  'chad kroeger': 6,
#  'bloodshed': 6,
#  'halfteros': 6,
#  'rod wave': 6,
#  'bishop': 6,
#  'jonas brothers': 6,
#  'jenna leigh green': 6,
#  'keili lefkovitz': 6,
#  'keith murray': 6,
#  'his orchestra': 6,
#  'jimmy buffett': 6,
#  'james ingram': 6,
#  'queen pen': 6,
#  'frank ocean': 6,
#  'heavy d': 6,
#  'big gipp': 6,
#  'rjay ty': 6,
#  'wizzy wow': 6,
#  'lil tecca': 6,
#  'mac lethal': 6,
#  'taio cruz': 6,
#  'alison krauss': 6,
#  'niro': 6,
#  'lil nas x': 6,
#  'ankhten brown': 6,
#  'kool g rap': 5,
#  'bilal': 5,
#  'nelly furtado': 5,
#  'powder p': 5,
#  'lil scrappy': 5,
#  'nerone': 5,
#  'carolina gaitán': 5,
#  'marques houston': 5,
#  'sons of funk': 5,
#  'kenny g': 5,
#  'big kap': 5,
#  'mick jagger': 5,
#  'chyna whyte': 5,
#  'the heavytrackerz': 5,
#  "lil' will": 5,
#  'diana ross': 5,
#  'linda ronstadt': 5,
#  'toby keith': 5,
#  'so large': 5,
#  'eric church': 5,
#  'bon iver': 5,
#  'ted gerow': 5,
#  'fish mooney': 5,
#  'carly simon': 5,
#  'bone crusher': 5,
#  'marvin gaye': 5,
#  'krizz kaliko': 5,
#  'olga merediz': 5,
#  'nardo wick': 5,
#  'blo/b': 5,
#  'neil young': 5,
#  'monica': 5,
#  'armageddon': 5,
#  'gun black': 5,
#  'lanz khan': 5,
#  'dierks bentley': 5,
#  'firefly': 5,
#  'otis redding': 5,
#  "disney's friends for change": 5,
#  'bootsy collins': 5,
#  'jewell': 5,
#  'clean bandit': 5,
#  'loon': 5,
#  'c+c music factory': 5,
#  'just shawn': 5,
#  "destiny's child": 5,
#  'avery storm': 5,
#  'cassidy': 5,
#  'fat bub': 5,
#  'oswald cobblepot': 5,
#  'anonimo': 5,
#  'hitman': 5,
#  'chris rivers': 5,
#  'encanto - cast': 5,
#  'iyaz': 5,
#  'wizkid': 5,
#  'john mayer': 5,
#  'notxxxayne': 5,
#  'morgan wallen': 5,
#  'young gliss': 5,
#  'brandi williams': 5,
#  'case': 5,
#  'mo thugs': 5,
#  'gksttar': 5,
#  'tony bennett': 5,
#  'five man electrical band': 5,
#  'digbargayraps': 5,
#  'eric nally': 5,
#  'diplo': 5,
#  'benny blanco': 5,
#  'peabo bryson': 5,
#  'yung bleu': 5,
#  'anderson .paak': 5,
#  'trina': 5,
#  'alesso': 5,
#  'rick belanger': 5,
#  'felicia': 5,
#  'mozzy': 5,
#  'joe budden': 5,
#  'luke combs': 5,
#  'yungstar': 5,
#  'webbie': 5,
#  'thug queen': 5,
#  'chris young': 5,
#  'luke bryan': 5,
#  'martin garrix': 5,
#  'fat pat': 5,
#  'abbie kearse': 5,
#  'cardinal troublemaker': 5,
#  'the alan parsons project': 5,
#  'rhenzy feliz': 5,
#  'mc hammer': 5,
#  "o'dell": 5,
#  'martha wash': 5,
#  'gen': 5,
#  'kolossalkocks': 5,
#  'n.o.r.e.': 5,
#  'kandi': 5,
#  'big hawk': 5,
#  'manga saint hilare': 5,
#  'est gee': 5,
#  'meddaman': 5,
#  'mack 10': 5,
#  'madonna': 5,
#  "michel'le": 5,
#  'julia michaels': 5,
#  'bj the chicago kid': 5,
#  'skepta': 5,
#  'total': 5,
#  'lo keys': 5,
#  'frankie j': 5,
#  'brian rading': 5,
#  'jon connor': 5,
#  'john denver': 5,
#  "lil' troy": 5,
#  'grandmaster caz': 5,
#  'reece west': 5,
#  'fiend': 5,
#  'murphy lee': 5,
#  'layzie bone': 5,
#  'beanie sigel': 5,
#  'doja cat': 5,
#  'ynw melly': 5,
#  'teddy riley': 5,
#  'alice cooper': 5,
#  'gmoses': 5,
#  'jackboys': 5,
#  'full force': 5,
#  'bryan adams': 5,
#  'aerosmith': 5,
#  'warez': 5,
#  'earthgang': 5,
#  'jim jones': 5,
#  'brian mcknight': 5,
#  'mo b. dick': 5,
#  'mauro castillo': 5,
#  'paul hardcastle': 5,
#  "ol' dirty bastard": 5,
#  'ronald isley': 5,
#  'steve aoki': 5,
#  'nigpro': 5,
#  'kristen bell': 5,
#  'mia x': 5,
#  'deepmaniac80': 5,
#  'moko lab, blo/b': 5,
#  'vuugi p': 5,
#  'ell brain': 5,
#  'george strait': 5,
#  'funkadelic': 5,
#  'lil flip': 5,
#  'lloyd': 5,
#  'pras': 5,
#  'gym class heroes': 5,
#  'mr freeze': 5,
#  'maren morris': 5,
#  'high school musical cast': 5,
#  'ivy pepper': 5,
#  'mtv': 5,
#  'diane guerrero': 5,
#  'mike belanger': 5,
#  'les emmerson': 5,
#  'blu': 5,
#  'big t': 5,
#  'en vogue': 5,
#  'santana': 5,
#  'bobby v': 5,
#  'donna summer': 5,
#  'jessie j': 4,
#  'kardinal offishall': 4,
#  'crystal lewis': 4,
#  'big mato': 4,
#  'david banner': 4,
#  'jermaine jackson': 4,
#  'hardy': 4,
#  'cory monteith': 4,
#  'bing crosby': 4,
#  'rittz': 4,
#  'shmorky': 4,
#  'david crosby': 4,
#  'moby': 4,
#  'becky g.': 4,
#  'keala settle': 4,
#  'jhay cortez': 4,
#  '8ball': 4,
#  'thundercat': 4,
#  'nicolette larson': 4,
#  'aaron hall': 4,
#  'honeymoon in vegas ensemble': 4,
#  'vince staples': 4,
#  'skeme': 4,
#  'copywrite': 4,
#  'stunna 4 vegas': 4,
#  'fifth harmony': 4,
#  'johntá austin': 4,
#  'george clinton': 4,
#  'jason aldean': 4,
#  'prince': 4,
#  'kris kristofferson': 4,
#  'mario winans': 4,
#  'sugarland': 4,
#  'd&d (g-ko': 4,
#  'kuzgun': 4,
#  'nle choppa': 4,
#  'original broadway cast of next to normal': 4,
#  'dev': 4,
#  'mark "toxic" hughes': 4,
#  'chris stapleton': 4,
#  'madsonik': 4,
#  '9th wonder': 4,
#  'lea michele': 4,
#  'george jones': 4,
#  'dave dee': 4,
#  'maxxi.p': 4,
#  'belly': 4,
#  'gza': 4,
#  'pumpkinhead': 4,
#  'rapsody': 4,
#  'garrett nash': 4,
#  'alice ripley': 4,
#  'oswin benjamin': 4,
#  'gorillaz': 4,
#  'jennifer damiano': 4,
#  'rylo rodriguez': 4,
#  'kevin rudolf': 4,
#  'raphael saadiq': 4,
#  'james brown': 4,
#  'warren\xa0g': 4,
#  'the greatest showman ensemble': 4,
#  'lady wray': 4,
#  'johnny gill': 4,
#  'sammy davis jr.': 4,
#  'sylk-e. fyne': 4,
#  'slash': 4,
#  'hugh jackman': 4,
#  'eazy-e': 4,
#  "rappin' 4-tay": 4,
#  'la chat': 4,
#  'the diplomats': 4,
#  'ray j': 4,
#  'lemon demon': 4,
#  'danielgotskillz': 4,
#  'original broadway cast of honeymoon in vegas': 4,
#  'the bad seed': 4,
#  'riemeloare': 4,
#  'freddie foxxx': 4,
#  'beaky': 4,
#  'hillary scott': 4,
#  'infared': 4,
#  ...}

# %%
#bins = np.linspace(min(degrees), max(degrees), 10)
bins = np.logspace(0, np.log10(max(degrees)), 10)
density = True
hist, edges = np.histogram(degrees, bins=bins, density = density)
x = (edges[1:] + edges[:-1])/2
width = bins[1] - bins[0]

fig, ax = plt.subplots()
#ax.bar(x, hist, width=width_rand*0.9)
ax.plot(x, hist, marker='.')

ax.set_xlabel('degrees')
if density:
    ax.set_ylabel('probability density')
else:
    ax.set_ylabel('counts')
    
ax.set_yscale("log")
ax.set_xscale("log")

# %%
con_com = nx.algorithms.connected_components(G)
largest_cc = max(nx.connected_components(G), key=len)
gia_com = G.subgraph(largest_cc)
avg_sho_pat_len = nx.average_shortest_path_length(gia_com)
print(f'Avg. shortest path length: {avg_sho_pat_len:.5f}')
# Out:
# Avg. shortest path length: 4.99602
